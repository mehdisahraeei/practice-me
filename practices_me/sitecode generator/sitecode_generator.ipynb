# %%
import pandas as pd
import random
import string

def generate_new_code():
    letter1 = random.choice(string.ascii_lowercase)
    number = random.randint(1, 999)
    letters2 = ''.join(random.choices(string.ascii_lowercase, k=2))
    ending = random.choice(['0', '1'])
    return f"MTR_{letter1}{number}{letters2}{ending}"

df = pd.read_csv("info.csv")

df['site code'] = [generate_new_code() for _ in range(len(df))]

df.to_csv("info_updated.csv", index=False)

# %%
df.head()
# Out:
#      site code sharing-status site type tower type  tower height  \
# 0  MTR_m296ku1            yes   Outdoor   Monopole          24.0
# 1  MTR_h493ie1             no    Indoor    Lattice          42.0
# 2  MTR_a217xd0             no    Indoor    Lattice          30.0
# 3  MTR_d203xr1            yes   Outdoor   Monopole          24.0
# 4  MTR_e458wf1            yes    Indoor    Lattice          44.0
#
#     tech number-2G   tech number-3G   tech number-4G   tech number-5G  \
# 0              2.0              3.0              1.0              1.0
# 1              1.0              3.0              2.0              0.0
# 2              3.0              3.0              2.0              1.0
# 3              1.0              1.0              2.0              2.0
# 4              3.0              3.0              3.0              2.0
#
#   company-antenna  ...  antenna tip of sector 4  power sepration amper  \
# 0          Huawei  ...                   8X-pol                   25.0
# 1          Huawei  ...                   8X-pol                  288.0
# 2          Huawei  ...                   8X-pol                  300.0
# 3          Huawei  ...                   8X-pol                   25.0
# 4          Huawei  ...                   8X-pol                  434.0
#
#    power sharing coding power type  pahse coding  diesel generator  \
# 0                   MCI         AC           3.0             ?????
# 1                    TM         AC           3.0              ????
# 2                    TM         DC           3.0              ????
# 3                   MCI         AC           3.0             ?????
# 4                    TM         DC           3.0              ????
#
#    calc Amper radio image tag  link type  percent of being full
# 0         1.0               0      Fiber                   95.0
# 1        50.0               3      Fiber                   77.0
# 2       125.0               3  Fiber-TCX                   66.0
# 3         1.0               0      Fiber                   55.0
# 4       125.0               1     BW-ETH                   66.0
#
# [5 rows x 35 columns]
