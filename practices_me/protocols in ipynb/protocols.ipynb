# %% [markdown]
# ### importing libs

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### ping

# %%
_list = !ping -c 3 blogfa.com

# %%
_list = _list[:4]
_list
# Out:
# ['PING blogfa.com (158.69.187.205) 56(84) bytes of data.',
#  '64 bytes from ip205.ip-158-69-187.net (158.69.187.205): icmp_seq=1 ttl=109 time=307 ms',
#  '64 bytes from ip205.ip-158-69-187.net (158.69.187.205): icmp_seq=2 ttl=109 time=307 ms',
#  '64 bytes from ip205.ip-158-69-187.net (158.69.187.205): icmp_seq=3 ttl=109 time=227 ms']

# %%
df1 = pd.DataFrame(_list,columns=['info'])
df1.head()
# Out:
#                                                 name
# 0  PING blogfa.com (158.69.187.205) 56(84) bytes ...
# 1  64 bytes from ip205.ip-158-69-187.net (158.69....
# 2  64 bytes from ip205.ip-158-69-187.net (158.69....
# 3  64 bytes from ip205.ip-158-69-187.net (158.69....

# %%
d1.to_csv('ping.csv')

# %% [markdown]
# ### arp

# %%
_arp = !arp -n

# %%
b
# Out:
#                                                 info
# 0  Address                  HWtype  HWaddress    ...
# 1  192.168.1.1              ether   10:fe:ed:66:8...

# %%
df2.to_csv('arp.csv')

# %% [markdown]
# ### netstat

# %%
_nstat = !netstat -na
_nstat
# Out:
# ['Active Internet connections (servers and established)',
#  'Proto Recv-Q Send-Q Local Address           Foreign Address         State      ',
#  'tcp        0      0 127.0.0.1:631           0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:8888          0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 0.0.0.0:7070            0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:49459         0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:33035         0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:57829         0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:59853         0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:36673         0.0.0.0:*               LISTEN     ',
#  'tcp        0      0 127.0.0.1:52327         0.0.0.0:*               LISTEN     ',
# ...

# %%
df3 = pd.DataFrame(_nstat,columns=['info'])
df3.head()
# Out:
#                                                 info
# 0  Active Internet connections (servers and estab...
# 1  Proto Recv-Q Send-Q Local Address           Fo...
# 2  tcp        0      0 127.0.0.1:631           0....
# 3  tcp        0      0 127.0.0.1:8888          0....
# 4  tcp        0      0 0.0.0.0:7070            0....

# %%
df3.to_csv('netstat.csv')
